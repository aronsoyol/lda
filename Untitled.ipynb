# %%
import jieba

# %%
jieba.load_userdict("mydict_cn.txt")
jieba.suggest_freq('云计算', True)
jieba.suggest_freq('区块链', True)
jieba.suggest_freq("物联网", True)
jieba.suggest_freq("大数据", True)
jieba.suggest_freq("智能终端", True)
jieba.suggest_freq("长达", True)
jieba.suggest_freq("低带宽", True)
jieba.suggest_freq("莫伦科夫", True)
jieba.suggest_freq("乐视网", True)
jieba.suggest_freq("饿了吗", True)
jieba.suggest_freq("于亚辉", True)
jieba.suggest_freq("配送员", True)
jieba.suggest_freq("送餐员", True)

jieba.suggest_freq("黑科技", True)
jieba.suggest_freq("王东华", True)
jieba.suggest_freq("风投", True)
jieba.suggest_freq("剁手", True)
jieba.suggest_freq("双11", True)
jieba.suggest_freq("双12", True)
jieba.suggest_freq("线上", True)
jieba.suggest_freq("线下", True)
jieba.suggest_freq("业态", True)

jieba.suggest_freq("下单", True)

jieba.suggest_freq("活下来", True)
jieba.suggest_freq("近场支付", True)
jieba.suggest_freq("连锁商", True)
jieba.suggest_freq("死掉", True)
jieba.suggest_freq("张轩松", True)
jieba.suggest_freq("生鲜品", True)
jieba.suggest_freq("品类", True)
jieba.suggest_freq("电商", True)
jieba.suggest_freq("快递员", True)
jieba.suggest_freq("站在未", True)
jieba.suggest_freq("皆木健司", True)
jieba.suggest_freq("很好", True)
jieba.suggest_freq("活下来", True)
jieba.suggest_freq("活下来", True)
jieba.suggest_freq("活下来", True)
jieba.suggest_freq("活下来", True)
jieba.suggest_freq("活下来", True)
jieba.suggest_freq("活下来", True)
jieba.suggest_freq("活下来", True)
# Out:
# 64

# %%
l = jieba.cut("链条产业链区块链供应链资金链花钱电商品类")
for w in l:
    print(w)
# Out:
# 链条
# 产业链
# 区块链
# 供应链
# 资金
# 链
# 花钱
# 电
# 商品
# 类

# %%
from collections import defaultdict

# %%
lines = []
wdic = defaultdict(lambda :0)
with open("/Users/aron/xinhua/txt_xinhua/0002391986.txt")as file:
    for line in file:
        lines.append(line.strip())
l = jieba.cut("".join(lines))
for w in l:
    wdic[w] += 1

for w, c in wdic.items():
    print(w, c)
# Out:
# http 1
# : 1
# / 6
# www 1
# . 3
# xinhuanet 1
# com 1
# tech 1
# 2017 3
# - 6
# 12 3
# c 1
# _ 1
# 1122097792 1
# htm 1
# 京东 31
# 物流 81
# 组局 1
# 全球 5
# 新一代 11
# 峰会 6
#   23
# 首倡 2
# “ 18
# 共生 14
# ” 14
# 发展 17
# 理念 5
# 月 1
# 11 1
# 日 1
# ， 150
# 由 1
# 主办 1
# 的 109
# 在 25
# 北京 1
# 举行 2
# CEO 2
# 王振辉 7
# 上 2
# 表示 8
# 消费 4
# 、 73
# 产业 6
# 升级 3
# 和 26
# 技术 9
# 变革 8
# 作用 2
# 之下 1
# 将 19
# 迈入 1
# 新 12
# 时代 5
# 并 5
# 呈现出 2
# 短链 4
# 智慧 10
# 特征 2
# 。 52
# 未来 9
# 角色 2
# 被 2
# 重新 2
# 定义 2
# 倡导 3
# 与 15
# 客户 3
# 行业 7
# 合作伙伴 4
# 以及 1
# 环境 1
# 希望 3
# 大家 2
# 共同 4
# 推动 3
# 整个 4
# 社会 7
# 共同进步 1
# 巨头 3
# 汇聚 2
# 探讨 2
# 物流业 3
# 是 9
# 支撑 2
# 国民经济 1
# 基础性 1
# 战略性 1
# 随着 5
# 模式 3
# 业态 1
# 不断涌现 1
# 不再 1
# 只是 1
# 连接 1
# 生产 1
# 端 1
# 销售 1
# 端的 1
# 工具 1
# 逐渐 3
# 成为 8
# 厂商 1
# 终端 2
# 消费者 6
# 虚拟 1
# 经济 3
# 实体 1
# 之间 1
# 重要 2
# 链条 2
# 系统 4
# 中 5
# 不断 11
# 正在 3
# 经历 1
# 巨大 1
# 此次 2
# 以 5
# 无 5
# 界 5
# 为 10
# 主题 1
# 了 7
# 行业协会 1
# 商界 1
# 及 3
# DHL 3
# 法国 2
# 邮政 2
# 雅 4
# 玛多 4
# Fedex 1
# 顺丰 2
# 普洛斯 3
# 等 9
# ...
